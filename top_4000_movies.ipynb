# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('top_4000_movies_data.csv', index_col = 0)

# %%
df
# Out:
#                                               Movie Title  Production Budget  \
# Release Date
# 4/23/2019                               Avengers: Endgame          400000000
# 5/20/2011     Pirates of the Caribbean: On Stranger Tides          379000000
# 4/22/2015                         Avengers: Age of Ultron          365000000
# 12/16/2015           Star Wars Ep. VII: The Force Awakens          306000000
# 4/25/2018                          Avengers: Infinity War          300000000
# ...                                                   ...                ...
# 6/13/2067                             You Only Live Twice            9500000
# 6/10/1988                                 Poltergeist III            9500000
# 12/21/2016                                         Dangal            9500000
# 3/19/2010                                    The Runaways            9500000
# 10/30/2009                              Gentlemen Broncos            9500000
#
# ...

# %%
df.isna().sum()
# Out:
# Movie Title          0
# Production Budget    0
# Domestic Gross       0
# Worldwide Gross      0
# dtype: int64

# %%
df1 = df.groupby('Release Date')

# %%
df1.first()
# Out:
#                                  Movie Title  Production Budget  \
# Release Date
# 1/1/1970                  The Molly Maguires           11000000
# 1/1/1975                        Barry Lyndon           11000000
# 1/1/1978                            Caravans           14000000
# 1/1/1979                     The Deer Hunter           15000000
# 1/1/1980                  Lion of the Desert           35000000
# ...                                      ...                ...
# 9/9/2005                  An Unfinished Life           30000000
# 9/9/2009                                   9           30000000
# 9/9/2011                           Contagion           60000000
# 9/9/2015      Maze Runner: The Scorch Trials           61000000
# 9/9/2016            The Disappointments Room           15000000
#
#               Domestic Gross  Worldwide Gross
# Release Date
# 1/1/1970             2200000          2200000
# 1/1/1975            20000000         20169934
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 4/23/2019 to 10/30/2009
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Movie Title        4000 non-null   object
#  1   Production Budget  4000 non-null   int64
#  2   Domestic Gross     4000 non-null   int64
#  3   Worldwide Gross    4000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 156.2+ KB

# %%
df.max()
# Out:
# Movie Title          長江七號 (CJ7)
# Production Budget     400000000
# Domestic Gross        936662225
# Worldwide Gross      2845899541
# dtype: object

# %%
df.sort_values(by=['Worldwide Gross'],ascending = False)
# Out:
#                                        Movie Title  Production Budget  \
# Release Date
# 12/17/2009                                  Avatar          237000000
# 4/23/2019                        Avengers: Endgame          400000000
# 12/18/1997                                 Titanic          200000000
# 12/16/2015    Star Wars Ep. VII: The Force Awakens          306000000
# 4/25/2018                   Avengers: Infinity War          300000000
# ...                                            ...                ...
# 10/3/2014                               Drive Hard           12000000
# 8/25/2017                               Death Note           40000000
# 11/8/2019                                    Klaus           40000000
# NaN                                         Reagan           25000000
# 12/11/2015                        The Ridiculous 6           60000000
#
#               Domestic Gross  Worldwide Gross
# Release Date
# 12/17/2009         760507625       2845899541
# ...

# %%
df2 = df.nlargest(10, ['Worldwide Gross'])

# %%
df2
# Out:
#                                        Movie Title  Production Budget  \
# Release Date
# 12/17/2009                                  Avatar          237000000
# 4/23/2019                        Avengers: Endgame          400000000
# 12/18/1997                                 Titanic          200000000
# 12/16/2015    Star Wars Ep. VII: The Force Awakens          306000000
# 4/25/2018                   Avengers: Infinity War          300000000
# 6/9/2015                            Jurassic World          215000000
# 7/11/2019                            The Lion King          260000000
# 4/1/2015                                 Furious 7          190000000
# 4/25/2012                             The Avengers          225000000
# 11/20/2019                               Frozen II          150000000
#
#               Domestic Gross  Worldwide Gross
# Release Date
# 12/17/2009         760507625       2845899541
# 4/23/2019          858373000       2797800564
# ...

# %%
df2.sort_values(by=['Release Date'])
# Out:
#                                        Movie Title  Production Budget  \
# Release Date
# 11/20/2019                               Frozen II          150000000
# 12/16/2015    Star Wars Ep. VII: The Force Awakens          306000000
# 12/17/2009                                  Avatar          237000000
# 12/18/1997                                 Titanic          200000000
# 4/1/2015                                 Furious 7          190000000
# 4/23/2019                        Avengers: Endgame          400000000
# 4/25/2012                             The Avengers          225000000
# 4/25/2018                   Avengers: Infinity War          300000000
# 6/9/2015                            Jurassic World          215000000
# 7/11/2019                            The Lion King          260000000
#
#               Domestic Gross  Worldwide Gross
# Release Date
# 11/20/2019         477373578       1445182280
# 12/16/2015         936662225       2064615817
# ...

# %%
df.dtypes
# Out:
# Movie Title          object
# Production Budget     int64
# Domestic Gross        int64
# Worldwide Gross       int64
# dtype: object
